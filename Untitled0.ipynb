# %%
# !nvidia-smi

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive/yolo9/yolov9
# Out:
# /content/drive/MyDrive/yolo9/yolov9

# %%
# !python train_dual.py --workers 8 --batch 4 --img 640 --epochs 10 --data /content/drive/MyDrive/yolo9/yolov9/data.yaml --weights /content/drive/MyDrive/yolo9/yolov9-e-converted.pt --device 0 --cfg /content/drive/MyDrive/yolo9/yolov9/models/detect/yolov9_custom.yaml --hyp /content/drive/MyDrive/yolo9/yolov9/data/hyps/hyp.scratch-high.yaml
# Out:
# 2024-04-08 15:08:31.601650: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-04-08 15:08:31.601697: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-04-08 15:08:31.603135: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-04-08 15:08:32.659948: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# ...

# %%
# %cd /content/drive/MyDrive/yolo9/yolov9
# Out:
# /content/drive/MyDrive/yolo9/yolov9

# %%
# !python detect.py --img 1080 --conf 0.1 --device 0 --weights /content/drive/MyDrive/yolo9/yolov9/runs/train/exp4/weights/best.pt --source /content/drive/MyDrive/yolo9/qw.jpg
# Out:
# detect: weights=['/content/drive/MyDrive/yolo9/yolov9/runs/train/exp4/weights/best.pt'], source=/content/drive/MyDrive/yolo9/qw.jpg, data=data/coco128.yaml, imgsz=[1080, 1080], conf_thres=0.1, iou_thres=0.45, max_det=1000, device=0, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLO 🚀 v0.1-78-gaa38db1 Python-3.10.12 torch-2.2.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
#
# Fusing layers...
# yolov9_custom summary: 580 layers, 60498220 parameters, 0 gradients
# WARNING ⚠️ --img-size [1080, 1080] must be multiple of max stride 32, updating to [1088, 1088]
# image 1/1 /content/drive/MyDrive/yolo9/qw.jpg: 1088x1088 14 -s, 17 Tinyperosns, 168.2ms
# Speed: 1.1ms pre-process, 168.2ms inference, 492.8ms NMS per image at shape (1, 3, 1088, 1088)
# ...

# %%
from IPython.display import Image
Image(filename="/content/drive/MyDrive/yolo9/yolov9/runs/detect/exp7/qw.jpg", width=600)

# %%
# %cd /content/drive/MyDrive/yolo9/yolov9
# Out:
# /content/drive/MyDrive/yolo9/yolov9

# %%
# !python train_dual.py --workers 8 --batch 4 --img 640 --epochs 10 --data /content/drive/MyDrive/yolo9/yolov9/data.yaml --weights /content/drive/MyDrive/yolo9/yolov9-e.pt --device 0 --cfg /content/drive/MyDrive/yolo9/yolov9/models/detect/yolov9_custom.yaml --hyp /content/drive/MyDrive/yolo9/yolov9/data/hyps/hyp.scratch-high.yaml
# Out:
# 2024-04-12 07:37:37.438961: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-04-12 07:37:37.439032: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-04-12 07:37:37.440732: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-04-12 07:37:39.069048: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# ...

# %%
# %cd /content/drive/MyDrive/yolo9/yolov9
# Out:
# /content/drive/MyDrive/yolo9/yolov9

# %%
# !python detect.py --conf 0.08 --device 0 --weights /content/drive/MyDrive/yolo9/yolov9/runs/train/exp7/weights/best.pt --source /content/drive/MyDrive/yolo9/v3.mp4
# Out:
# detect: weights=['/content/drive/MyDrive/yolo9/yolov9/runs/train/exp7/weights/best.pt'], source=/content/drive/MyDrive/yolo9/v3.mp4, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.08, iou_thres=0.45, max_det=1000, device=0, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLO 🚀 v0.1-78-gaa38db1 Python-3.10.12 torch-2.2.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
#
# Fusing layers...
# yolov9_custom summary: 580 layers, 60498220 parameters, 0 gradients
# video 1/1 (1/903) /content/drive/MyDrive/yolo9/v3.mp4: 384x640 1 Tinyperosn, 247.9ms
# video 1/1 (2/903) /content/drive/MyDrive/yolo9/v3.mp4: 384x640 1 Tinyperosn, 59.1ms
# video 1/1 (3/903) /content/drive/MyDrive/yolo9/v3.mp4: 384x640 1 Tinyperosn, 59.0ms
# ...
